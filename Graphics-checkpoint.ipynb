# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataset=pd.read_csv("complete_data.csv",sep=';',index_col="Id")

# %%
numerical=['BsmtFinSF1',"BsmtFinSF2","EnclosedPorch",'Fireplaces','FullBath','GarageArea','GarageCars','GrLivArea','HalfBath',
           'KitchenAbvGr','LotArea','LotFrontage','LowQualFinSF','MasVnrArea','MiscVal','OpenPorchSF',
           'OverallCond','OverallQual','PoolArea','ScreenPorch','TotRmsAbvGrd','TotalBsmtSF','WoodDeckSF','BedroomAbvGr',
           'BsmtUnfSF','BsmtHalfBath','BsmtFullBath','3SsnPorch','2ndFlrSF','1stFlrSF']

# %%
def create_split(value):
    if value<1413.0:
        return "<= 1413.0"
    else:
        return "> 1413.0"

# %%
def create_hue(value):
    if value<803.5:
        return "<= 803.5"
    elif value<1198.5:
        return "<= 1198.5"
    elif value<1413.0:
        return "<= 1413.0"
    elif value<1488.0:
        return "<= 1488.0"
    elif value<1825.0:
        return "<= 1825.0"
    elif value<2361:
        return "<= 2361"
    elif value<3550.5:
        return "<= 3550.5"
    else:
        return "> 3550.5"

# %%
split_values=[1488.0,1198.5,803.5,1413.0]

# %%
X_train["hue_split"]=X_train["GrLivArea"].apply(create_hue)

# %%
# Out:
# array(['<= 2361', '<= 1413.0', '<= 1198.5', '> 2361', '<= 803.5',
#        '<= 1488.0'], dtype=object)

# %%
if X_train["LivSplit3"]==

#map_func={"<= 1413.0":1,}
X_train["hue_split"]=X_train

# %%
X_train3=X_train2[X_train2["LivSplit2"]=="<= 1198.5"]

# %%
splits=('<= 803.5','<= 1198.5','<= 1413.0','<= 1488.0','<= 1825.0','<= 2361','<= 3550.5','> 3550.5')

# %%
means={}
for i in X_train["hue_split"].unique():
    print(i)
    means[i]=X_train[X_train["hue_split"]==i]["SalePrice"].mean()
# Out:
# <= 803.5
# <= 1198.5
# <= 1413.0
# <= 1488.0
# <= 1825.0
# <= 2361
# <= 3550.5
# > 3550.5

# %%
sorted(means.values())
# Out:
# [89009.8085106383,
#  124965.92857142857,
#  152815.83673469388,
#  172635.48453608248,
#  197442.1689373297,
#  239358.13362068965,
#  313656.01136363635,
#  490791.6666666667]

# %%
sns.lmplot(x="GrLivArea", y="SalePrice",hue="hue_split",fit_reg=False,data=X_train,
               truncate=False, size=8,)
plt.savefig("living_area_total.png")

# %%
#GrLivArea , OverallQual

# %%
sns.lmplot(x="YearBuilt", y="SalePrice",fit_reg=True,data=dataset,
               truncate=False, size=8,)

# %%
X_train["OverallQual"].hist()

# %%
sns.lmplot(x="YearBuilt", y="SalePrice",hue="YearDummy",fit_reg=True,data=dataset,
               truncate=False, size=8,)

# %%
X_tr=pd.read_csv("X_train.csv",sep=';',index_col="Id")
y_tr=pd.read_csv("y_train.csv",sep=';',index_col="Id")
X_te = pd.read_csv("X_test.csv",sep=';',index_col="Id")
train_len = len(X_tr)

# %%
'LotArea' "GrLivArea"

# %%
X_train=pd.DataFrame()
X_test=pd.DataFrame()
variables=["GrLivArea"]
for i in variables:
    X_train[i]=X_tr[i]
    X_test[i]=X_te[i]

# %%
X_train["SalePrice"]=y_tr["SalePrice"]

# %%
X_train.drop("SalePrice",axis=1,inplace=True)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree=DecisionTreeRegressor(random_state=42,max_depth=3)
#max_depth=3

# %%
dtree.fit(X_train, y_tr)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='best')

# %%
predictions=dtree.predict(X_test)

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn.tree import export_graphviz
import pydot

# %%
X_train.head()
# Out:
#     BsmtFinSF1  BsmtFinSF2  EnclosedPorch  Fireplaces  FullBath  GarageArea  \
# Id
# 1        706.0         0.0              0           0         2       548.0
# 2        978.0         0.0              0           1         2       460.0
# 3        486.0         0.0              0           1         2       608.0
# 4        216.0         0.0            272           1         1       642.0
# 5        655.0         0.0              0           1         2       836.0
#
#     GarageCars  GrLivArea  HalfBath  KitchenAbvGr    ...     TotRmsAbvGrd  \
# Id                                                   ...
# 1          2.0       1710         1             1    ...                8
# 2          2.0       1262         0             1    ...                6
# 3          2.0       1786         1             1    ...                6
# 4          3.0       1717         0             1    ...                7
# 5          3.0       2198         1             1    ...                9
#
# ...

# %%
names=[]
for i in range(len(labels)):
    names.append(labels[i])

# %%
X_train.head()
# Out:
#     GrLivArea  SalePrice
# Id
# 1        1710   208500.0
# 2        1262   181500.0
# 3        1786   223500.0
# 4        1717   140000.0
# 5        2198   250000.0

# %%
X_train.drop("Dummy",axis=1,inplace=True)

# %%
#visualisation of decision tree
#X_train.drop("SalePrice",axis=1,inplace=True)
labels=list(X_train.drop("SalePrice",axis=1).columns.values)


from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,  
                filled=True,max_depth=0, rounded=True,feature_names=labels,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())
#plt.savefig('tree.png')
#feature_names=[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[6]]
graph.write_png("houseprice_livi_depth0.png")
# Out:
# True

# %%
X_train.head()
# Out:
#     GrLivArea  hue_split  SalePrice
# Id
# 1        1710  <= 1825.0   208500.0
# 2        1262  <= 1413.0   181500.0
# 3        1786  <= 1825.0   223500.0
# 4        1717  <= 1825.0   140000.0
# 5        2198    <= 2361   250000.0

# %%
X_train.iloc[2]
# Out:
# GrLivArea         1786
# hue_split    <= 1825.0
# SalePrice       223500
# Name: 3, dtype: object

# %%
#decision tree regressor try

mse={}
counter=0
def split_dataset(value):
    if value < split_point:
        return 1
    else:
        return 0


for i in sorted(X_train["GrLivArea"].unique()):
    if counter<1:
        next
    counter+=1
    split_point=i
    mean=[]
    X_train["Dummy"]=X_train["GrLivArea"].apply(split_dataset)
    mean.append(X_train[X_train["Dummy"]==1]["SalePrice"].mean())
    mean.append(X_train[X_train["Dummy"]==0]["SalePrice"].mean())
    mse_value=0
    for a in X_train[X_train["Dummy"]==1]["SalePrice"]:
        mse_value=mse_value+(a-mean[0])*(a-mean[0])
    if len(X_train[X_train["Dummy"]==1]["SalePrice"])>0:
        mse[i]=mse_value/len(X_train[X_train["Dummy"]==1]["SalePrice"])

# %%
# first group the whole dataset in larger and smaller than value.
#get mean for both slices

# %%
sns.lmplot(x="GrLivArea",y="SalePrice",size=8,fit_reg=False,data=X_train)
plt.savefig("living_nosplit.png")

# %%
# visualize instability of decision tree regressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
states=[0,101,42,250]
dtree=DecisionTreeRegressor(random_state=42,max_depth=3) 
feature_importances={}
for i in range(len(states)):
    X_train_split, X_eval, y_train_split, y_eval = train_test_split(X_train,y_train, test_size=0.2,random_state=states[i])
    dtree.fit(X_train_split, y_train_split)
    labels=list(X_train_split.columns.values)
    dot_data = StringIO()
    export_graphviz(dtree, out_file=dot_data,  
                    filled=True, rounded=True,feature_names=labels,
                    special_characters=True)
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    feature_importances[i]=dtree.feature_importances_
    Image(graph.create_png())
    #graph.write_png("houseprice"+str(i)+".png")

# %%
# Out:
# 4

# %%
#clustered feature importance
importance=pd.read_csv("Importances_clustered.csv",delimiter=";")

# %%
importance.head()
# Out:
#        feature importance
# 0    GrLivArea   0,131367
# 1     1stFlrSF   0,079056
# 2   BsmtFinSF1  0,0674533
# 3      LotArea  0,0588004
# 4  OverallQual  0,0454277

# %%
xlabels=['GrLivArea',
 '1stFlrSF',
 'BsmtFinSF1',
 'LotArea',
 'OverallQual',
 'TotalBsmtSF',
 'OverallCond',
 '2ndFlrSF',
 'YearBuilt',
 'ScreenPorch',
 'BsmtExposure',
 'YearRemodAdd',
 'PoolArea',
 'age_garage',
 'BsmtQual',
 'GarageArea',
 'Neighborhood_Crawfor',
 'FireplaceQu',
 'LotFrontage',
 'BsmtFinType1',
 'OpenPorchSF',
 'Exterior1st_BrkFace',
 'GarageCars',
 'total_age',
 'KitchenQual',
 'WoodDeckSF',
 'Functional_Typ',
 'BsmtUnfSF',
 'SaleCondition_Abnorml',
 'Condition1_Norm']

# %%
X_train=pd.read_csv("X_train.csv",sep=';',index_col="Id")
importances=importance["importance"]

# %%
indices = np.argsort(importances)[::]

# %%
indices = np.argsort(importances)[::-1]
labels=list(X_train.columns.values)
variables=30
plt.figure()
plt.figure(figsize=(15,10))
plt.title("Feature importances (first 30)")
plt.bar(range(len(importances[indices][:variables])), importances[indices][:variables],
       color="b",align="center") 
plt.xticks(range(len(importances[indices][:variables])), xlabels,rotation=80)
plt.xlim([-1, len(importances[indices][:variables])])
plt.tight_layout()

#saving figure
#plt.savefig('xgb_feature_importance_30.png')

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train=pd.read_csv("train.csv",index_col="Id")
gesamt_var=list(train.columns.values)

# %% [markdown]
# possible Variables to start explanation: BsmtUnfSF, WoodDeckSf, OpenPorchSf,LotArea, 1stFlrSF

# %%
numerical=['BsmtFinSF1',"BsmtFinSF2","EnclosedPorch",'Fireplaces','FullBath','GarageArea','GarageCars','GrLivArea','HalfBath',
           'KitchenAbvGr','LotArea','LotFrontage','LowQualFinSF','MasVnrArea','MiscVal','OpenPorchSF',
           'OverallCond','OverallQual','PoolArea','ScreenPorch','TotRmsAbvGrd','TotalBsmtSF','WoodDeckSF','BedroomAbvGr',
           'BsmtUnfSF','BsmtHalfBath','BsmtFullBath','3SsnPorch','2ndFlrSF','1stFlrSF']

# %%
for i in numerical:
    sns.lmplot(x=i,y="SalePrice",size=8,fit_reg=True,data=train)
